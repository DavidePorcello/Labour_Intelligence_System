# %%
import Topic_modeling
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.rcParams["figure.figsize"]=20,20
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\david\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
everything = Topic_modeling.Topic_modeling('corpse.xls', 'everything')

# %%
data_lemmatized = everything.data_lemmatized

# %%
data_lemmatized
# Out:
# [['branch',
#   'share',
#   'nice',
#   'update',
#   'time',
#   'pleasure',
#   'team',
#   'come_join',
#   'team',
#   'offer',
#   'agriculture',
#   'production',
#   'logistic',
#   'housing',
#   'transport',
#   'support',
#   'peral_level',
#   'stay',
#   'register',
#   'webster',
#   'recruit',
#   'contact',
#   'agrojobsh_growwithus',
#   'agrochamp'],
#  ['good',
#   'accommodation',
#   'transport',
#   'contact',
#   'peral_level',
#   'register',
#   'today',
#   'website',
#   'sobs',
#   'potato',
#   'couple',
#   'register',
#   'register'],
#  ['flowerfriday',
#   'ago',
#   'part',
#   'team',
#   'work',
#   'rico',
#   'select',
#   'lip',
#   'bme',
#   'cleveland',
#   'register',
#   'webster',
#   'opportunity',
#   'famflowerfarm',
#   'agrojobsh_growwithus',
#   'wkend'],
#  ['flowerfriday',
#   'ago',
#   'client',
#   'start',
#   'select',
#   'lip',
#   'field',
#   'register',
#   'webster',
#   'opportunity',
#   'famflowerfarm',
#   'agrojobsh_growwithus',
#   'wkend'],
#  ['passionate',
#   'trunk',
#   'technical',
#   'insight',
#   'enthusiastic',
#   'expece',
#   'mechanic',
#   'truck',
#   'mechanic',
#   'able',
#   'indndently',
#   'carry',
#   'maintenance',
#   'repairaltro',
#   'identify',
#   'report',
#   'defect',
#   'equipment',
#   'carry',
#   'repair',
#   'requirement',
#   'capacity',
#   'indndently',
#   'motivation',
#   'commitment',
#   'willing',
#   'learn',
#   'mentality',
#   'expece',
#   'similar_position',
#   'pession',
#   'driving_lice',
#   'english',
#   'medium',
#   'advanced',
#   'level',
#   'offer',
#   'develop',
#   'knowledge',
#   'skill',
#   'passionate',
#   'dedicated',
#   'team',
#   'attractive',
#   'salary',
#   'option',
#   'grow',
#   'salary',
#   'obtain',
#   'various',
#   'certificate',
#   'good',
#   'accommodation',
#   'transport',
#   'contact',
#   'peral_level',
#   'register',
#   'webster',
#   'agrojobsh_growwithus'],
#  ['aline',
#   'share',
#   'nice',
#   'update',
#   'time',
#   'pleasure',
#   'team',
#   'agrojobsh_growwithus',
#   'agrochamp'],
#  ['spring',
#   'place',
#   'admire',
#   'colourful',
#   'bming',
#   'julie',
#   'field',
#   'gard',
#   'take',
#   'sunglass',
#   'put',
#   'winter',
#   'clothe',
#   'away',
#   'come',
#   'day',
#   'spring',
#   'weather',
#   'shine',
#   'agrojobsh_growwithus'],
#  ['paprika',
#   'grnhouse',
#   'start',
#   'soon',
#   'activity',
#   'happy',
#   'join',
#   'team',
#   'agrojobsh',
#   'sea',
#   'growwithus',
#   'vaine',
#   'joel_left',
#   'september',
#   'ore',
#   'facebook',
#   'andro'],
#  ['ago',
#   'ago',
#   'employ',
#   'opportunity',
#   'improve',
#   'life',
#   'grow',
#   'carr',
#   'earn',
#   'salary',
#   'deserve',
#   'also',
#   'havealtro',
#   'additional',
#   'service',
#   'employment',
#   'housing',
#   'transport',
#   'medical_insurance',
#   'assistance',
#   'peral_level',
#   'register',
#   'today',
#   'webster',
#   'cum',
#   'centre',
#   'loculus',
#   'much',
#   'land',
#   'strange',
#   'skontaktujemy_sir',
#   'agrojobsh_growwithus'],
#  ['flowerfriday',
#   'ago',
#   'today',
#   'pick',
#   'fresh',
#   'flower',
#   'flower',
#   'shop',
#   'bm',
#   'gm',
#   'office',
#   'wish',
#   'happy',
#   'wkend',
#   'register',
#   'webster',
#   'opportunity',
#   'agrojobsh_growwithus',
#   'wkend'],
#  ['lovely',
#   'winter',
#   'weather',
#   'produce',
#   'exceptionally',
#   'dangerous',
#   'slippery',
#   'road',
#   'surface',
#   'would',
#   'ask',
#   'extra',
#   'careful',
#   'commune',
#   'wise',
#   'leave',
#   'time',
#   'asaltro',
#   'visibility',
#   'less',
#   'road',
#   'busy',
#   'addition',
#   'window',
#   'car',
#   'flog',
#   'wise',
#   'let',
#   'car',
#   'time',
#   'aware',
#   'cold',
#   'trature',
#   'extra',
#   'travel',
#   'time',
#   'quion',
#   'contact',
#   'coordinate',
#   'careful',
#   'stay_safe',
#   'maybe',
#   'enjoy',
#   'snow',
#   'spare',
#   'time',
#   'agrojobsh_growwithus'],
#  ['flowerfriday',
#   'ago',
#   'careful',
#   'stay_safe',
#   'come',
#   'winter',
#   'weather',
#   'wish',
#   'happy',
#   'wkend',
#   'register',
#   'webster',
#   'opportunity',
#   'agrojobsh_growwithus',
#   'wkend'],
#  ['winter',
#   'wonder',
#   'land',
#   'snow',
#   'lover',
#   'may',
#   'get',
#   'ice',
#   'state',
#   'canal',
#   'come',
#   'wkend',
#   'meteorologist',
#   'predict',
#   'centimetre',
#   'snow',
#   'wkend',
#   'able',
#   'saltro',
#   'first',
#   'snowflake',
#   'night',
#   'saturday',
#   'sunday',
#   'face',
#   'serious',
#   'winter',
#   'weather',
#   'ice',
#   'snow',
#   'frost',
#   'low_trature',
#   'due',
#   'icy',
#   'east',
#   'wind',
#   'saturday',
#   'trature',
#   'lip',
#   'everywhere',
#   'country',
#   'follow',
#   'ice',
#   'day',
#   'driver',
#   'advice',
#   'careful',
#   'drive',
#   'icy',
#   'road',
#   'take',
#   'extra',
#   'travel',
#   'time',
#   'enjoy',
#   'winter',
#   'agrojobsh_growwithus'],
#  ['flowerfriday',
#   'ago',
#   'office',
#   'decorate',
#   'exquisite',
#   'red',
#   'lip',
#   'wish',
#   'happy',
#   'wkend',
#   'order',
#   'beautiful',
#   'bouquet',
#   'lip',
#   'register',
#   'webster',
#   'opportunity',
#   'agrojobsh_growwithus',
#   'wkend'],
#  ['happy',
#   'receive',
#   'beautifully',
#   'pack',
#   'bouquet',
#   'lip',
#   'stay',
#   'tune',
#   'flowerfriday',
#   'picture',
#   'agrojobsh_growwithus',
#   'rico',
#   'tulpennu'],
#  ['day',
#   'treat',
#   'next',
#   'thing',
#   'buy',
#   'fresh',
#   'product',
#   'straight',
#   'local',
#   'good',
#   'cycle',
#   'drive',
#   'walk',
#   'room',
#   'visit',
#   'many',
#   'stall',
#   'farm',
#   'shop',
#   'way',
#   'middenmr',
#   'niece',
#   'niedorp',
#   'ingerwerf',
#   'find',
#   'fresh',
#   'flower',
#   'chse',
#   'milk',
#   'jam',
#   'fruit',
#   'vegetable',
#   'fish',
#   'local',
#   'product',
#   'product',
#   'check',
#   'facebook_page',
#   'frieze',
#   'lat',
#   'update',
#   'agrojobsh_growwithus',
#   'ajhnew',
#   'standtogether'],
#  ['excavation',
#   'news',
#   'webster',
#   'officially',
#   'live',
#   'order',
#   'lovely',
#   'bouquet',
#   'lip',
#   'home',
#   'office',
#   'surprise',
#   'love',
#   'agrojobsh',
#   'rico',
#   'tulpennu',
#   'growtogether',
#   'gennooo',
#   'facebook',
#   'android',
#   'doorway',
#   'time',
#   'come',
#   'officially',
#   'online',
#   'check',
#   'webster',
#   'beautiful',
#   'lip',
#   'directly',
#   'grover',
#   'home'],
#  ['today',
#   'january',
#   'night',
#   'time',
#   'cure',
#   'come',
#   'force',
#   'mean',
#   'everyone',
#   'stay',
#   'inside',
#   'betwn',
#   'pm',
#   'lot',
#   'employsaltro',
#   'essential',
#   'sector',
#   'provide',
#   'form',
#   'employer',
#   'declaration',
#   'cure',
#   'send',
#   'message',
#   'employ',
#   'information',
#   'cure',
#   'measure',
#   'recd',
#   'read',
#   'message',
#   'carefully',
#   'quion',
#   'want',
#   'information',
#   'contact',
#   'coordinate',
#   'agrojobsh_growwithus'],
#  ['frighten',
#   'may',
#   'order',
#   'fresh',
#   'lip',
#   'agrojobsh_growwithus',
#   'gennooo',
#   'facebook',
#   'android',
#   'break',
#   'news',
#   'day',
#   'launch',
#   'webshop',
#   'buy',
#   'lip',
#   'directly',
#   'grover',
#   'verser',
#   'fresh',
#   'eye',
#   'page',
#   'miss',
#   'anything'],
#  ['raise',
#   'aware',
#   'importance',
#   'agriculture',
#   'genius',
#   'innovative',
#   'network',
#   'grow',
#   'create',
#   'dawn',
#   'roosegaarde',
#   'dawn',
#   'roosegaarde',
#   'world',
#   'movie',
#   'premier',
#   'grow',
#   'highlight',
#   'beauty',
#   'agriculture',
#   'luminous',
#   'dreamscape',
#   'red',
#   'blue',
#   'light',
#   'wave',
#   'enormous',
#   'field',
#   'grow',
#   'inspire',
#   'light',
#   'science',
#   'exploringaltro',
#   'certain',
#   'light',
#   'recipe',
#   'improve',
#   'plant',
#   'growth',
#   'reduce',
#   'use',
#   'picide',
#   'watch',
#   'full',
#   'scrn',
#   'sound',
#   'hopeful',
#   'light',
#   'dark',
#   'time',
#   'stay',
#   'tune',
#   'art',
#   'science',
#   'project',
#   'collaboration',
#   'rabobank',
#   'wagen',
#   'university',
#   'research',
#   'mediamonk',
#   'many',
#   'other',
#   'grow',
#   'food',
#   'agriculture',
#   'farming',
#   'daanroosegaarde',
#   'roosegaarde',
#   'design',
#   'innovation'],
#  ['today',
#   'national',
#   'julie',
#   'day',
#   'ununately',
#   'big',
#   'pick',
#   'flower',
#   'garden',
#   'dam',
#   'previous',
#   'year',
#   'lip',
#   'still',
#   'brighten',
#   'day',
#   'picture',
#   'still',
#   'memorie',
#   'well',
#   'day',
#   'well',
#   'day',
#   'come',
#   'agrojobsh_growwithus',
#   'tuliptime',
#   'nostalgico',
#   'press',
#   'dam',
#   'gennaio',
#   'ore',
#   'land_settentrionale',
#   'past',
#   'basis',
#   'throwback',
#   'tulipday',
#   'ununately',
#   'tomorrow',
#   'julie',
#   'pick',
#   'garden',
#   'due',
#   'still',
#   'enjoy',
#   'beautiful',
#   'julie',
#   'party',
#   'last',
#   'year',
#   'kp',
#   'precious',
#   'ouraltro',
#   'memory',
#   'head',
#   'tulpenpluktuin',
#   'makar',
#   'sink',
#   'sd',
#   'genieten',
#   'van',
#   'practice',
#   'tulpenfst',
#   'doze',
#   'moore',
#   'herinnere',
#   'take',
#   'tuliptime',
#   'tilden',
#   'tulpeizoen',
#   'tulpentijd'],
#  ['year',
#   'receive',
#   'jaaropgave',
#   'annual',
#   'statement',
#   'employer',
#   'jaaropgave',
#   'basis',
#   'settlement',
#   'annual',
#   'tax',
#   'contain',
#   'data',
#   'salary',
#   'height',
#   'contribution',
#   'paidaltro',
#   'employer',
#   'annual',
#   'statement',
#   'income',
#   'tax',
#   'declaration',
#   'base',
#   'income',
#   'tax',
#   'declaration',
#   'dutch',
#   'tax',
#   'custom',
#   'administration',
#   'decide',
#   'entitled',
#   'debate',
#   'refund',
#   'excess',
#   'pay',
#   'tax',
#   'pay',
#   'extra',
#   'due',
#   'insufficient',
#   'tax',
#   'bn',
#   'pay',
#   'inform',
#   'dutch',
#   'annual',
#   'tax',
#   'declaration',
#   'soon',
#   'wkly',
#   'news',
#   'post',
#   'offer',
#   'variety',
#   'opportunity',
#   'agriculture',
#   'apply',
#   'webster',
#   'get',
#   'touch',
#   'soon',
#   'pible',
#   'zarejruj',
#   'inregistrare_agrojobsh',
#   'growwithus',
#   'open',
#   'people',
#   'pit',
#   'sponsorship'],
#  ['strict',
#   'lockdown',
#   'january',
#   'government',
#   'aim',
#   'regard',
#   'limit',
#   'contact',
#   'betwn',
#   'people',
#   'much',
#   'pible',
#   'lockdown',
#   'essential',
#   'shop',
#   'stillaltro',
#   'open',
#   'shop',
#   'nds',
#   'example',
#   'essential',
#   'shop',
#   'suparket',
#   'pharmacy',
#   'baker',
#   'butcher',
#   'drugstore',
#   'petrol',
#   'station',
#   'healthy',
#   'habit',
#   'wash',
#   'hand',
#   'regularly',
#   'cough',
#   'seize',
#   'elbow',
#   'use',
#   'paper',
#   'tissue',
#   'blow',
#   'nose',
#   'discard',
#   'use',
#   'shake',
#   'hand',
#   'other',
#   'wear',
#   'face',
#   'mask',
#   'stay',
#   'metre',
#   'arm',
#   'length',
#   'away',
#   'people',
#   'already',
#   'part',
#   'team',
#   'quion',
#   'contact',
#   'coordinate',
#   'team',
#   'ago',
#   'respect',
#   'appreciate',
#   'loyalty',
#   'wish',
#   'health',
#   'safety',
#   'agrojobsh_growwithus',
#   'ajhnew',
#   'staystrong'],
#  ['surprised',
#   'team',
#   'super',
#   'christmas',
#   'box',
#   'contain',
#   'regional',
#   'product',
#   'directly',
#   'customer',
#   'high_quality',
#   'product',
#   'good',
#   'story',
#   'passionate',
#   'farmer',
#   'producer',
#   'product',
#   'proud_partner',
#   'kwekerijdeingr',
#   'rainbowkleinpak',
#   'zuurbier',
#   'renébruin',
#   'patrickvan',
#   'biesheuvelknofk',
#   'kwekerijkraaien',
#   'hanmldijk',
#   'trifle',
#   'rico',
#   'gourmet',
#   'agrojobsh_growwithus',
#   'growtogether'],
#  ['north',
#   'bryant',
#   'good',
#   'bryant',
#   'province',
#   'south',
#   'population',
#   'ion',
#   'major',
#   'city',
#   'north',
#   'bryant',
#   'pop',
#   'kilburn',
#   'pop',
#   'also',
#   'bread',
#   'pop',
#   'provincial',
#   'capital',
#   'hertogenbosch',
#   'also',
#   'call',
#   'den',
#   'known',
#   'technology',
#   'design',
#   'hut',
#   'birthplace',
#   'philip',
#   'electronic',
#   'day',
#   'trunk',
#   'braia',
#   'second',
#   'busis',
#   'airport',
#   'also',
#   'situate',
#   'due',
#   'high',
#   'teach',
#   'environment',
#   'part',
#   'several',
#   'initiative',
#   'develop',
#   'foster',
#   'increase',
#   'brainport',
#   'top',
#   'technology',
#   'region',
#   'hertogenbosch',
#   'wonderful',
#   'city',
#   'full',
#   'historic',
#   'building',
#   'wonderful',
#   'museum',
#   'great',
#   'shop',
#   'welcome',
#   'case',
#   'raurant',
#   'go',
#   'stroll',
#   'discover',
#   'medieval',
#   'architecture',
#   'take',
#   'boat',
#   'tour',
#   'century',
#   'old',
#   'canal',
#   'system',
#   'go',
#   'bicycle',
#   'ride',
#   'resse',
#   'city',
#   'visit',
#   'north',
#   'bryant',
#   'agrojobsh_growwithus',
#   'explorethursday',
#   'thisish'],
#  ['end',
#   'great',
#   'appreciate',
#   'great',
#   'individual',
#   'christian',
#   'similar',
#   'vaine',
#   'marian',
#   'branch',
#   'marina',
#   'michael',
#   'stepan',
#   'work',
#   'hard',
#   'pleasure',
#   'cropaltro',
#   'rotation',
#   'get',
#   'grnhouse',
#   'ready',
#   'new',
#   'sea',
#   'happy',
#   'team',
#   'agrojobsh',
#   'want',
#   'wish',
#   'great',
#   'wkend',
#   'register',
#   'webster',
#   'agriculture',
#   'growwithus',
#   'appreciation'],
#  ['province',
#   'population',
#   'ion',
#   'november',
#   'population',
#   'dity',
#   'km',
#   'make',
#   'country',
#   'populous',
#   'province',
#   'world',
#   'dely',
#   'populated',
#   'area',
#   'cover',
#   'area',
#   'km',
#   'also',
#   'know',
#   'nhage',
#   'hague',
#   'capital',
#   'province',
#   'seat',
#   'government',
#   'host',
#   'international',
#   'court',
#   'justice',
#   'important',
#   'court',
#   'world',
#   'second',
#   'larg',
#   'city',
#   'population',
#   'larg',
#   'european',
#   'union',
#   'populous',
#   'country',
#   'major',
#   'logistic',
#   'economic',
#   'centre',
#   'europe',
#   'larg',
#   'seaport',
#   'city',
#   'visit',
#   'agrojobsh_growwithus',
#   'explorethursday',
#   'thisish'],
#  ['provide',
#   'decent',
#   'housing',
#   'worker',
#   'equip',
#   'necessity',
#   'home',
#   'long',
#   'day',
#   'ago',
#   'also',
#   'take_care',
#   'utility',
#   'wife',
#   'connection',
#   'soaltro',
#   'extra',
#   'cost',
#   'provide',
#   'accommodation',
#   'dutch',
#   'style',
#   'house',
#   'apartment',
#   'residential',
#   'complex',
#   'forget',
#   'living',
#   'room',
#   'kitchen',
#   'room',
#   'bedroom_share',
#   'accommodation',
#   'colleague',
#   'couple',
#   'always',
#   'accommodate',
#   'together',
#   'bedroom',
#   'housing',
#   'location',
#   'standard',
#   'stick',
#   'order',
#   'flexwonen',
#   'foundation',
#   'flexible',
#   'housing',
#   'standard',
#   'sn',
#   'standard',
#   'distinguishe',
#   'subject',
#   'space',
#   'privacy',
#   'sanitary',
#   'provision',
#   'safety',
#   'hygienic',
#   'provision',
#   'information',
#   'provision',
#   'requirement',
#   'fire',
#   'safety',
#   'agrojobsh',
#   'admit',
#   'sn',
#   'register',
#   'authorize',
#   'use',
#   'sn',
#   'quality',
#   'mark',
#   'log',
#   'agrojobsh_growwithus'],
#  ['provide',
#   'local',
#   'transport',
#   'company',
#   'car',
#   'fresh',
#   'modern',
#   'fully',
#   'equip',
#   'give',
#   'employ',
#   'peace',
#   'mind',
#   'drive',
#   'perform',
#   'onaltro',
#   'company',
#   'car',
#   'available',
#   'transport',
#   'employment',
#   'use',
#   'together',
#   'colleague',
#   'regulation',
#   'use',
#   'company',
#   'car',
#   'communicate',
#   'arrival',
#   'enjoy',
#   'ride',
#   'agrojobsh_growwithus'],
#  ['office',
#   'locate',
#   'airport',
#   'middenmr',
#   'would',
#   'visit',
#   'office',
#   'read',
#   'information',
#   'health',
#   'wing',
#   'staff',
#   'client',
#   'worker',
#   'remainsaltro',
#   'priority',
#   'implement',
#   'measure',
#   'minimise',
#   'prevent',
#   'spread',
#   'virus',
#   'become',
#   'secure',
#   'workplace',
#   'staff',
#   'remote',
#   'matter',
#   'deal',
#   'telephone',
#   'video',
#   'call',
#   'email',
#   'online',
#   'essay',
#   'face',
#   'face',
#   'mte',
#   'require',
#   'appointment',
#   'visit',
#   'office',
#   'pre',
#   'arranged',
#   'appointment',
#   'pible',
#   'encourage',
#   'communicate',
#   'telephone',
#   'email',
#   'agrojobsh_growwithus'],
#  ['secure',
#   'perfect',
#   'skill',
#   'lifyle',
#   'start',
#   'agency',
#   'pass',
#   'interview',
#   'formality',
#   'home',
#   'country',
#   'stop',
#   'also',
#   'series',
#   'formality',
#   'complete',
#   'first',
#   'sign',
#   'individual',
#   'employment',
#   'contract',
#   'agency',
#   'contract',
#   'language',
#   'example',
#   'rumania',
#   'polish',
#   'dutch',
#   'make',
#   'easy',
#   'understand',
#   'worry',
#   'part',
#   'ago',
#   'competent',
#   'team',
#   'guide',
#   'way',
#   'way',
#   'make_sure',
#   'process',
#   'easy',
#   'fast',
#   'correct',
#   'offer',
#   'variety',
#   'opportunity',
#   'agriculture',
#   'apply',
#   'webster',
#   'get',
#   'touch',
#   'soon',
#   'pible',
#   'zarejruj',
#   'inregistrare_agrojobsh',
#   'growwithus',
#   'open',
#   'people',
#   'pit',
#   'sponsorship'],
#  ['land',
#   'cut',
#   'cabbage',
#   'full_swing',
#   'complementary',
#   'outstanding',
#   'lip',
#   'back',
#   'colleague',
#   'florid',
#   'also',
#   'want',
#   'become',
#   'part',
#   'team',
#   'ago',
#   'simple',
#   'stepsaltro',
#   'schedule',
#   'interview',
#   'recruit',
#   'go',
#   'webster',
#   'fill',
#   'datum',
#   'application_form',
#   'recruit',
#   'contact',
#   'interview',
#   'agrojobsh_growwithus',
#   'glory',
#   'glory',
#   'october',
#   'ore'],
#  ['step',
#   'away',
#   'become',
#   'part',
#   'team',
#   'ago',
#   'order',
#   'choose',
#   'right',
#   'candidate',
#   'create',
#   'recruitment',
#   'system',
#   'simple',
#   'fast',
#   'pible',
#   'sching',
#   'interview',
#   'simple',
#   'simple',
#   'step',
#   'nd',
#   'get',
#   'touch',
#   'go',
#   'webster',
#   'fill',
#   'datum',
#   'application_form',
#   'recruit',
#   'contact',
#   'sap',
#   'interview',
#   'interview',
#   'get',
#   'detail',
#   'current',
#   'offer',
#   'suit',
#   'expece',
#   'next',
#   'step',
#   'become',
#   'member',
#   'team',
#   'agrojobsh_growwithus'],
#  ['october',
#   'breast',
#   'cancer',
#   'aware',
#   'month',
#   'annual',
#   'campaign',
#   'hs',
#   'increase',
#   'attention',
#   'support',
#   'aware',
#   'early',
#   'detection',
#   'treatment',
#   'palliative',
#   'care',
#   'disease',
#   'dedicate',
#   'buy',
#   'pink',
#   'bouquet',
#   'ser',
#   'donate',
#   'part',
#   'revenue',
#   'breast',
#   'cancer',
#   'research',
#   'agrojobsh_growwithus',
#   'pinkmonth'],
#  ['harve',
#   'cabbage',
#   'agricultural',
#   'capital',
#   'room',
#   'translate',
#   'dutch',
#   'crown',
#   'webster',
#   'information',
#   'register',
#   'agriculture',
#   'agrojobsh_growwithus',
#   'uitzendbureau'],
#  ['harve',
#   'cabbage',
#   'azerbaijani',
#   'way',
#   'agrojobsh',
#   'agriculture',
#   'farmlife',
#   'sustainability',
#   'taste',
#   'life',
#   'october',
#   'ore',
#   'azerbaijani',
#   'family',
#   'harving',
#   'cabbage',
#   'cook',
#   'delicious',
#   'meal'],
#  ['cabbage',
#   'harv',
#   'full_swe',
#   'cabbage',
#   'harver',
#   'currently',
#   'dominate',
#   'strt',
#   'scene',
#   'village',
#   'hrhugowaard',
#   'hard',
#   'do',
#   'team',
#   'several',
#   'plotsaltro',
#   'cut',
#   'cabbage',
#   'store',
#   'inter',
#   'expece',
#   'cut',
#   'cabbage',
#   'register',
#   'webster',
#   'agrojobsh_growwithus',
#   'workinh',
#   'uitzendbureau'],
#  ['choose',
#   'agrojobsh',
#   'benefit',
#   'many',
#   'advantage',
#   'regardless',
#   'provide',
#   'follow',
#   'employ',
#   'legal',
#   'employment',
#   'contract',
#   'compaltro',
#   'dutch',
#   'legislation',
#   'local',
#   'transport',
#   'provide',
#   'company',
#   'car',
#   'bus',
#   'equipment',
#   'accommodation',
#   'furniture',
#   'appliance',
#   'utility',
#   'include',
#   'extra',
#   'charge',
#   'medical_insurance',
#   'extra',
#   'charge',
#   'peral',
#   'support',
#   'coordinate',
#   'language',
#   'wkly',
#   'salary',
#   'payment',
#   'including_payslip',
#   'offer',
#   'wkly',
#   'agriculture',
#   'crucial',
#   'food',
#   'sector',
#   'protocol',
#   'ure',
#   'health',
#   'long',
#   'rule',
#   'follow',
#   'safe',
#   'register',
#   'webster',
#   'recruitment',
#   'team',
#   'contact',
#   'interview',
#   'growwithus',
#   'agriculture',
#   'airport',
#   'rumania',
#   'poland',
#   'open',
#   'people',
#   'pit',
#   'sponsorship'],
#  ['also',
#   'saturday',
#   'great',
#   'team',
#   'use',
#   'zuurbi',
#   'harve',
#   'ice',
#   'lecture',
#   'take',
#   'moment',
#   'make',
#   'groupselfie',
#   'grt',
#   'team',
#   'agrojobsh',
#   'gun',
#   'proud',
#   'team',
#   'wish',
#   'awesome',
#   'saturday',
#   'growwithus',
#   'tearworn',
#   'fun'],
#  ['constantly',
#   'grow',
#   'always',
#   'kout',
#   'believe',
#   'people',
#   'always',
#   'encourage',
#   'ownership',
#   'train',
#   'peral',
#   'guidance',
#   'end',
#   'potential',
#   'successful',
#   'carr',
#   'agrojobsh_growwithus'],
#  ['cabbage',
#   'sea',
#   'start',
#   'september',
#   'december',
#   'agrojobsh',
#   'strong',
#   'man',
#   'cut',
#   'cabbage',
#   'growwithus',
#   'register',
#   'webster',
#   'cabbagesea',
#   'agriculture'],
#  ['team',
#   'harve',
#   'client',
#   'ago',
#   'ago',
#   'produce',
#   'thancelery',
#   'year',
#   'agriculture',
#   'come_join',
#   'agrojobsh',
#   'theatre',
#   'register',
#   'online',
#   'webster',
#   'http',
#   'http',
#   'inregistrare',
#   'growwithus',
#   'proud',
#   'agriculture'],
#  ['proud',
#   'great',
#   'man',
#   'agrojobsh',
#   'agriculture',
#   'join',
#   'team',
#   'agrojobsh_growwithus'],
#  ['always',
#   'time',
#   'good',
#   'self',
#   'part',
#   'team',
#   'agrojobsh',
#   'michael',
#   'michael',
#   'share',
#   'lovely',
#   'photo',
#   'goodaltro',
#   'accommodation',
#   'transport',
#   'contact',
#   'peral_level',
#   'register',
#   'today',
#   'webster',
#   'strange',
#   'zarejruj',
#   'cum',
#   'centre',
#   'loculus',
#   'much',
#   'land',
#   'inregistrare',
#   'growwithus',
#   'workagency',
#   'patrol',
#   'recruitment',
#   'agriculturejobs'],
#  ['proud',
#   'office',
#   'locate',
#   'capital',
#   'agriculture',
#   'agriculture',
#   'join',
#   'team',
#   'agrojobsh_growwithus'],
#  ['flowerfriday',
#   'ago',
#   'spoil',
#   'joel_left',
#   'beautiful',
#   'flower',
#   'wish',
#   'happy',
#   'wkend',
#   'agriculture',
#   'check',
#   'webster',
#   'information',
#   'agrojobsh_growwithus',
#   'wkend'],
#  ['team',
#   'sort',
#   'flowerbulb',
#   'use',
#   'next',
#   'year',
#   'harv',
#   'agriculture',
#   'offer',
#   'variety',
#   'opportunity',
#   'agriculture',
#   'apply',
#   'webster',
#   'get',
#   'touch',
#   'soon',
#   'pible',
#   'agrojobsh_growwithus',
#   'worknow'],
#  ['wkly',
#   'welcome',
#   'new',
#   'colleague',
#   'team',
#   'get',
#   'information',
#   'agency',
#   'workplace',
#   'assistance',
#   'period',
#   'join',
#   'team',
#   'agriculture',
#   'altroagrojobsh',
#   'good',
#   'accommodation',
#   'transport',
#   'contact',
#   'peral_level',
#   'register',
#   'today',
#   'webster',
#   'strange',
#   'skontaktujemy_sir',
#   'http',
#   'cum',
#   'site',
#   'notre',
#   'si',
#   'contact',
#   'http',
#   'inregistrare',
#   'growwithus'],
#  ['monday',
#   'goal',
#   'start',
#   'sea',
#   'agrojobsh',
#   'agriculture',
#   'offer',
#   'variety',
#   'opportunity',
#   'agriculture',
#   'apply',
#   'webster',
#   'get',
#   'touch',
#   'soon',
#   'pible',
#   'agrojobsh_growwithus',
#   'worknow'],
#  ['yearly',
#   'team',
#   'strong',
#   'motivate',
#   'young',
#   'man',
#   'harv',
#   'ton',
#   'ice',
#   'lecture',
#   'client',
#   'summer',
#   'agriculture',
#   'webster',
#   'agrojobsh_growwithus'],
#  ['today',
#   'want',
#   'introduce',
#   'milan',
#   'rumania',
#   'stare',
#   'begin',
#   'enjoy',
#   'variety',
#   'offer',
#   'year',
#   'moment',
#   'milan',
#   'field',
#   'harvingaltro',
#   'lecture',
#   'milan',
#   'great',
#   'team',
#   'webster',
#   'information',
#   'agrojobsh_growwithus'],
#  ['day',
#   'grnhouse',
#   'pick',
#   'pepper',
#   'lovely',
#   'employ',
#   'maria',
#   'trust',
#   'agency',
#   'wish',
#   'good',
#   'time',
#   'inaltro',
#   'agriculture',
#   'variety',
#   'agriculture',
#   'check',
#   'webster',
#   'register',
#   'online',
#   'agrojobsh_growwithus'],
#  ['employ',
#   'great',
#   'time',
#   'cut',
#   'penny',
#   'dutch',
#   'field',
#   'apply',
#   'webster',
#   'get',
#   'touch',
#   'soon',
#   'pible',
#   'zarejruj',
#   'inregistrare_agrojobsh',
#   'growwithus'],
#  ['employ',
#   'prepare',
#   'norwood',
#   'lupus',
#   'detail',
#   'register',
#   'today',
#   'webster',
#   'register',
#   'webster',
#   'contact',
#   'inregistrati',
#   'acum',
#   'pentru',
#   'oculi',
#   'lunch',
#   'land',
#   'inregistrare_agrojobsh',
#   'growwithus',
#   'agriculture'],
#  ['client',
#   'fre',
#   'pass',
#   'chrysanten',
#   'back',
#   'production',
#   'ununate',
#   'effect',
#   'corona',
#   'flower',
#   'industry',
#   'early',
#   'year',
#   'agrojobsh_growwithus',
#   'flower',
#   'agriculture'],
#  ['monday',
#   'goal',
#   'ago',
#   'offer',
#   'variety',
#   'opportunity',
#   'agriculture',
#   'apply',
#   'webster',
#   'get',
#   'touch',
#   'soon',
#   'pible',
#   'zarejruj',
#   'inregistrare_agrojobsh',
#   'growwithus'],
#  ['peru',
#   'enjoy',
#   'variety',
#   'provide',
#   'year',
#   'agriculture',
#   'moment',
#   'peru',
#   'make',
#   'sure',
#   'iceberg',
#   'lecture',
#   'harve',
#   'client',
#   'use',
#   'zuurbi',
#   'lovely',
#   'photo',
#   'enjoy',
#   'workwk',
#   'agrojobsh_growwithus',
#   'agriculture'],
#  ['wkend',
#   'welcome',
#   'milan',
#   'back',
#   'rumania',
#   'new',
#   'employ',
#   'rumania',
#   'milan',
#   'graduate',
#   'last',
#   'year',
#   'search',
#   'new',
#   'adventure',
#   'hear',
#   'ago',
#   'hisaltro',
#   'already',
#   'agency',
#   'wish',
#   'milan',
#   'new',
#   'employ',
#   'much',
#   'luck',
#   'success',
#   'future',
#   'agriculture',
#   'apply',
#   'agrojobsh_growwithus'],
#  ['wkly',
#   'director',
#   'joel_left',
#   'spoil',
#   'quality',
#   'flower',
#   'amazing',
#   'client',
#   'want',
#   'wish',
#   'great',
#   'wkend',
#   'great',
#   'agriculture',
#   'register',
#   'webster',
#   'agrojobsh',
#   'stayhealthy',
#   'staypositive'],
#  ['want',
#   'celebrate',
#   'team',
#   'client',
#   'employ',
#   'grow',
#   'happy',
#   'international',
#   'worker',
#   'day',
#   'everyone',
#   'agriculture',
#   'apply',
#   'agrojobsh',
#   'workagency',
#   'celebrate',
#   'appreciate'],
#  ['place',
#   'much',
#   'gland',
#   'tomato',
#   'pepperhouse',
#   'departure',
#   'mania',
#   'wedday',
#   'may',
#   'requirement',
#   'couple',
#   'year',
#   'english',
#   'allow',
#   'charge',
#   'commission'],
#  ['proudly',
#   'present',
#   'new',
#   'company',
#   'car',
#   'employ',
#   'use',
#   'new',
#   'car',
#   'fresh',
#   'modern',
#   'fully',
#   'equip',
#   'give',
#   'employ',
#   'peace',
#   'mind',
#   'drive',
#   'perform',
#   'enjoy',
#   'ride',
#   'nice',
#   'wkend',
#   'agrojobsh',
#   'workagency',
#   'companycar'],
#  ['ago',
#   'employ',
#   'make_sure',
#   'thousand',
#   'kill',
#   'fresh',
#   'fruit',
#   'vegetable',
#   'inspect',
#   'cut',
#   'mix',
#   'pack',
#   'deliver',
#   'hour',
#   'local',
#   'suparket',
#   'dynamicaltro',
#   'process',
#   'continue',
#   'come_join',
#   'team',
#   'register',
#   'webster',
#   'agrojobsh_growwithus'],
#  ['today',
#   'sugg',
#   'put',
#   'party',
#   'outfit',
#   'dancing',
#   'shoe',
#   'dance',
#   'home',
#   'taed',
#   'edge',
#   'grand',
#   'admire',
#   'dutch',
#   'flower',
#   'field',
#   'keukenhof',
#   'flower',
#   'garden',
#   'team',
#   'ago',
#   'wish',
#   'wonderful',
#   'saturday',
#   'slam',
#   'april',
#   'ore',
#   'meet',
#   'edge',
#   'grand',
#   'start',
#   'russen',
#   'plowman',
#   'keukenhof',
#   'tilden',
#   'quarantaine',
#   'fival',
#   'mkijken'],
#  ['top',
#   'quality',
#   'chrysantum',
#   'customer',
#   'red',
#   'van',
#   'pa',
#   'chrysantum',
#   'agrojobsh',
#   'flower',
#   'growwithus',
#   'grnhouse'],
#  ['ago',
#   'ago',
#   'employ',
#   'opportunity',
#   'improve',
#   'life',
#   'grow',
#   'carr',
#   'earn',
#   'salary',
#   'deserve',
#   'also',
#   'havealtro',
#   'additional',
#   'service',
#   'employment',
#   'housing',
#   'transport',
#   'medical_insurance',
#   'assistance',
#   'peral_level',
#   'come_join',
#   'team',
#   'register',
#   'webster',
#   'muncainolanda',
#   'pracawholandii'],
#  ['young',
#   'ch',
#   'ago',
#   'team',
#   'member',
#   'much',
#   'fun',
#   'learn',
#   'lot',
#   'goat',
#   'farm',
#   'today',
#   'difficult',
#   'new',
#   'rule',
#   'farmer',
#   'nowadays',
#   'still',
#   'believe',
#   'support',
#   'next',
#   'gen',
#   'farmer',
#   'always',
#   'next',
#   'generation',
#   'farmer',
#   'agrojobsh',
#   'nextgeneration',
#   'agriculture',
#   'farm'],
#  ['spring',
#   'least',
#   'row',
#   'happy',
#   'dancing',
#   'field',
#   'first',
#   'day',
#   'year',
#   'leave',
#   'shed',
#   'trade',
#   'beautiful',
#   'spring',
#   'weather',
#   'grn',
#   'grass',
#   'specific',
#   'video',
#   'today',
#   'event',
#   'confirm',
#   'klaveraas',
#   'klakaas',
#   'news',
#   'era',
#   'biretta',
#   'price',
#   'spring',
#   'delight',
#   'spring',
#   'cow',
#   'stable',
#   'winter',
#   'finally',
#   'allow',
#   'meadow',
#   'also',
#   'cow',
#   'farmer',
#   'john',
#   'anita',
#   'store'],
#  ['daily',
#   'evolve',
#   'food',
#   'production',
#   'processing',
#   'try',
#   'fulfill',
#   'crucial',
#   'role',
#   'current',
#   'food',
#   'supply',
#   'client',
#   'concern',
#   'health',
#   'andaltro',
#   'take',
#   'measure',
#   'everyone',
#   'healthy',
#   'client',
#   'organize',
#   'prevent',
#   'sinuse',
#   'workplace',
#   'follow',
#   'protocol',
#   'set',
#   'kp',
#   'safe',
#   'dutch',
#   'government',
#   'introduce',
#   'raft',
#   'new',
#   'measure',
#   'combat',
#   'coronavirus',
#   'march',
#   'quion',
#   'hesitate',
#   'call',
#   'coordinate',
#   'team',
#   'ago',
#   'respect',
#   'appreciate',
#   'loyalty',
#   'wish',
#   'safe',
#   'healthy',
#   'wkend',
#   'agrojobsh',
#   'full',
#   'service',
#   'employment',
#   'agency',
#   'ago'],
#  ['nic',
#   'time',
#   'year',
#   'leave',
#   'cargo',
#   'jump',
#   'air',
#   'team',
#   'selection',
#   'lip',
#   'newlife',
#   'spring',
#   'agrojobsh'],
#  ['production',
#   'food',
#   'foodprocessing',
#   'full_swing',
#   'moment',
#   'client',
#   'organize',
#   'prevent',
#   'sinuse',
#   'workplace',
#   'health',
#   'matter',
#   'decide',
#   'supply',
#   'allaltro',
#   'house',
#   'extra',
#   'product',
#   'stay_safe',
#   'clean',
#   'today',
#   'housing',
#   'disinfect',
#   'hand',
#   'soap',
#   'disinfect',
#   'hand',
#   'get',
#   'disinfect',
#   'hand',
#   'tissue',
#   'tip',
#   'wash',
#   'hand',
#   'frequently',
#   'soap',
#   'water',
#   'minimum',
#   'second',
#   'seize',
#   'elbow',
#   'use',
#   'paper',
#   'tissue',
#   'shake',
#   'hand',
#   'team',
#   'ago',
#   'respect',
#   'appreciate',
#   'loyalty',
#   'wish',
#   'safe',
#   'healthy',
#   'wkend',
#   'agrojobsh'],
#  ['lose',
#   'due',
#   'corona',
#   'effect',
#   'production',
#   'food',
#   'food',
#   'process',
#   'full_swing',
#   'moment',
#   'newaltro',
#   'colleague',
#   'ago',
#   'offer',
#   'good',
#   'agriculture',
#   'come_join',
#   'team',
#   'polish',
#   'rumania'],
#  ['dutch',
#   'courage',
#   'tuesday',
#   'evening',
#   'dutch',
#   'nation',
#   'show',
#   'appreciation',
#   'clap',
#   'hope',
#   'set',
#   'firework',
#   'support',
#   'health',
#   'care',
#   'staff',
#   'deal',
#   'coronavirus',
#   'hard',
#   'get',
#   'dear',
#   'colleague',
#   'client',
#   'continuous',
#   'support',
#   'loyalty',
#   'also',
#   'want',
#   'ana',
#   'bill',
#   'peru',
#   'amazing',
#   'picture',
#   'proudtobehuman',
#   'healthcare',
#   'respect',
#   'agrojobsh'],
#  ['ago',
#   'support',
#   'dutch',
#   'floriculture',
#   'earth',
#   'love',
#   'flower',
#   'flower',
#   'immediate',
#   'impact',
#   'happi',
#   'flower',
#   'long',
#   'positive',
#   'effect',
#   'mood',
#   'flower',
#   'make',
#   'intimate',
#   'connection',
#   'agrojobsh',
#   'buyflower'],
#  ['celebrate',
#   'wkend',
#   'swt',
#   'pantry',
#   'ion',
#   'dutch',
#   'lip',
#   'sort',
#   'pack',
#   'ship',
#   'world',
#   'come',
#   'international',
#   'woman',
#   'day',
#   'ago',
#   'proud_partner',
#   'rico',
#   'lefloro',
#   'agrojobsh',
#   'rico',
#   'lefloro',
#   'dutchtulip',
#   'workinh'],
#  ['julie',
#   'rea',
#   'full',
#   'progress',
#   'tonic',
#   'photo',
#   'credit',
#   'catherine',
#   'petricar',
#   'clavicular',
#   'talk',
#   'locate',
#   'pressico',
#   'sullen',
#   'dem',
#   'set',
#   'fainting',
#   'country',
#   'medie'],
#  ['peru',
#   'share',
#   'great',
#   'picture',
#   'part',
#   'team',
#   'agrojobsh',
#   'choose',
#   'agrojobsh',
#   'agriculture',
#   'register',
#   'webster'],
#  ['happy',
#   'international',
#   'julie',
#   'may',
#   'team',
#   'proud_partner',
#   'tonic',
#   'tonic',
#   'gennoio',
#   'today',
#   'julie',
#   'sea',
#   'officially',
#   'open',
#   'pick',
#   'garden',
#   'open',
#   'square',
#   'tonic',
#   'busy',
#   'provide',
#   'everyone',
#   'colourful',
#   'grove',
#   'lip'],
#  ['agriculture',
#   'inter',
#   'team',
#   'ago',
#   'offer',
#   'good',
#   'accommodation',
#   'transport',
#   'support',
#   'peral_level',
#   'register',
#   'webster'],
#  ['still',
#   'search',
#   'agriculture',
#   'currently',
#   'poland',
#   'rumania',
#   'would',
#   'like',
#   'ago',
#   'goodaltro',
#   'accommodation',
#   'transport',
#   'contact',
#   'peral_level',
#   'register',
#   'today',
#   'webster',
#   'strange',
#   'skontaktujemy_sir',
#   'http',
#   'contact',
#   'cum',
#   'centre',
#   'loculus',
#   'much',
#   'land',
#   'http',
#   'contact',
#   'full',
#   'service',
#   'employment',
#   'agency',
#   'ago'],
#  ['proud_partner',
#   'passing_superver',
#   'specialist',
#   'fruit',
#   'vegetable',
#   'pass',
#   'passing_superver',
#   'dicembre',
#   'good',
#   'news',
#   'caesar',
#   'real',
#   'salad',
#   'lumbo',
#   'suparkten',
#   'bn',
#   'elect',
#   'consumer',
#   'product',
#   'year',
#   'category',
#   'real',
#   'salad',
#   'salad',
#   'develop',
#   'pass',
#   'produce',
#   'supply',
#   'lumbo',
#   'price',
#   'also',
#   'important',
#   'recognition'],
#  ['teamwork',
#   'take',
#   'dream',
#   'natalia',
#   'peticaru',
#   'great',
#   'picture',
#   'natalia',
#   'peticaru',
#   'strong',
#   'maria',
#   'camarasan',
#   'other',
#   'november',
#   'middenmr'],
#  ['man',
#   'brave',
#   'enough',
#   'joined',
#   'team',
#   'harve',
#   'typical',
#   'dutch',
#   'vegetable',
#   'pale',
#   'enk',
#   'use',
#   'enkoampot',
#   'wash',
#   'potato',
#   'pale',
#   'consume',
#   'winter',
#   'dutch',
#   'household',
#   'funfact',
#   'duty',
#   'buy',
#   'ion',
#   'kill',
#   'pale',
#   'annual',
#   'basis',
#   'make',
#   'know',
#   'winter',
#   'vegetable',
#   'come_join',
#   'team'],
#  ['ardeleanu',
#   'vaine',
#   'share',
#   'great',
#   'video',
#   'harving',
#   'paprika',
#   'amazing',
#   'part',
#   'team',
#   'ago',
#   'ardeleanu',
#   'vaine',
#   'joel_left',
#   'september',
#   'ore',
#   'facebook',
#   'andro'],
#  ['summer',
#   'holiday',
#   'kiss',
#   'back',
#   'sch',
#   'do',
#   'register',
#   'webster',
#   'become',
#   'part',
#   'team',
#   'ago',
#   'offer',
#   'legal',
#   'dutch',
#   'contract',
#   'wklyaltro',
#   'payment',
#   'salary',
#   'including_payslip',
#   'contact',
#   'peral_level',
#   'local',
#   'transportation',
#   'company',
#   'car',
#   'housing',
#   'medical_insurance',
#   'inter',
#   'contact',
#   'register',
#   'contact',
#   'ago'],
#  ['agrojobsh',
#   'launch',
#   'webster',
#   'monday',
#   'find',
#   'information',
#   'team',
#   'service',
#   'register',
#   'stay',
#   'tune',
#   'come',
#   'soon',
#   'construction'],
#  ['laugh',
#   'always',
#   'therapy',
#   'satisfied',
#   'colleague',
#   'rainbow',
#   'kleinpak',
#   'love',
#   'love',
#   'agrojobsh',
#   'workinh',
#   'agriculture'],
#  ['june',
#   'first',
#   'pile',
#   'drive',
#   'new',
#   'office',
#   'agriport',
#   'middenmr',
#   'team',
#   'present',
#   'event',
#   'inform',
#   'progress',
#   'trotaltro',
#   'team',
#   'new',
#   'office',
#   'agriport',
#   'growth',
#   'agriport',
#   'growth',
#   'agriport',
#   'team',
#   'official',
#   'head',
#   'wedday',
#   'june',
#   'strike',
#   'first',
#   'mile',
#   'new',
#   'office',
#   'agriport',
#   'middenmr',
#   'inform',
#   'progress',
#   'proud',
#   'team',
#   'newoffice',
#   'airport',
#   'growth',
#   'agrojobsh'],
#  ['speak',
#   'ii',
#   'wonderful',
#   'photo',
#   'session',
#   'taed',
#   'duct',
#   'vary',
#   'amazing',
#   'team',
#   'ago',
#   'basis',
#   'agriculture',
#   'employment',
#   'agency',
#   'nature',
#   'farm',
#   'cow',
#   'grass',
#   'come_join',
#   'part',
#   'team',
#   'agrojobsh',
#   'workinh'],
#  ['red',
#   'pepper',
#   'fact',
#   'rise',
#   'ride',
#   'paprika',
#   'red',
#   'pepper',
#   'rise',
#   'ride',
#   'paprika',
#   'start',
#   'grn',
#   'change',
#   'color',
#   'leave',
#   'vine',
#   'long',
#   'also',
#   'turn',
#   'red',
#   'become',
#   'swt',
#   'nutt',
#   'example',
#   'red',
#   'pepper',
#   'time',
#   'beta',
#   'caroline',
#   'time',
#   'vitamin',
#   'time',
#   'vitamin',
#   'first',
#   'harve',
#   'grn',
#   'pepper',
#   'short',
#   'shelf',
#   'life',
#   'impact',
#   'price',
#   'red',
#   'pepper',
#   'thing',
#   'red',
#   'variety',
#   'expive',
#   'color',
#   'grocer',
#   'store',
#   'agrojobsh',
#   'workinh',
#   'muncainolanda',
#   'agriculture'],
#  ['colleague',
#   'joel_left',
#   'together',
#   'christian',
#   'onofrei',
#   'peticaru',
#   'michael',
#   'sort',
#   'paprika',
#   'great',
#   'client',
#   'rainbow',
#   'stay',
#   'close',
#   'employ',
#   'workactivitie',
#   'client',
#   'create',
#   'theatre',
#   'ultimate',
#   'dreamteam',
#   'contact',
#   'peral_level',
#   'guarantd',
#   'come_join',
#   'team',
#   'contact',
#   'poland',
#   'rumania'],
#  ['expece',
#   'worker',
#   'want',
#   'tomato',
#   'pepper',
#   'grnhouse',
#   'couple',
#   'woman',
#   'man',
#   'betwn',
#   'year',
#   'drain',
#   'take',
#   'top',
#   'snoeien',
#   'offer',
#   'newly',
#   'transport',
#   'rumania',
#   'orator',
#   'poland',
#   'expece',
#   'workactivitie',
#   'mention',
#   'inter',
#   'contact',
#   'romaniapoland',
#   'agrojobsh',
#   'grnhouse'],
#  ['join',
#   'team',
#   'agro',
#   'aprile',
#   'mlle',
#   'race',
#   'right',
#   'employ',
#   'client',
#   'grnhouse',
#   'paprika',
#   'consist',
#   'shine',
#   'pepper',
#   'couple',
#   'woman',
#   'man',
#   'nd',
#   'know',
#   'language',
#   'allegro',
#   'drive',
#   'cat',
#   'pibility',
#   'start',
#   'immediately',
#   'age',
#   'year',
#   'information',
#   'phone',
#   'mail',
#   'angelic'],
#  ['part',
#   'true',
#   'agricultural',
#   'employment',
#   'agency',
#   'come_join',
#   'team',
#   'leave',
#   'detail',
#   'private_message',
#   'colleague',
#   'contact',
#   'agrojobsh',
#   'jobsinh'],
#  ['salad',
#   'sea',
#   'corner',
#   'hardworke',
#   'colleague',
#   'realstrongman',
#   'come',
#   'back',
#   'sea',
#   'make_sure',
#   'do',
#   'agrojobsh',
#   'agriculture',
#   'saladsea',
#   'openfield'],
#  ['team',
#   'build',
#   'trip',
#   'team',
#   'lovely',
#   'time',
#   'rumania',
#   'great',
#   'visit',
#   'confirm',
#   'saltmi',
#   'turn',
#   'oneteam',
#   'agrojobsh'],
#  ['first',
#   'tulipfield',
#   'bming',
#   'know',
#   'worker',
#   'production',
#   'process',
#   'tulipfield',
#   'sort',
#   'julie',
#   'bulb',
#   'pack',
#   'lip',
#   'ready',
#   'ship',
#   'world',
#   'also',
#   'inter',
#   'agrojobsh',
#   'love',
#   'lip',
#   'contact',
#   'leave',
#   'telephone',
#   'number',
#   'private_message',
#   'agrojobsh',
#   'workagency',
#   'flower',
#   'lip',
#   'http'],
#  ['proud_partner',
#   'tonic',
#   'tonic',
#   'cargo',
#   'beautiful',
#   'flower',
#   'action',
#   'international',
#   'woman',
#   'may',
#   'provide',
#   'lady',
#   'siberia',
#   'england',
#   'nice',
#   'bunch',
#   'lip',
#   'lip',
#   'tonic',
#   'lefloro'],
#  ['flower',
#   'want',
#   'ago',
#   'workagency',
#   'trustworthy',
#   'wkly',
#   'payment',
#   'transparent',
#   'wkly',
#   'salaryslip',
#   'quality',
#   'greataltro',
#   'accommodation',
#   'service',
#   'contact',
#   'peral_level',
#   'flower',
#   'broad',
#   'include',
#   'many',
#   'activity',
#   'unload',
#   'flower',
#   'straight',
#   'auction',
#   'sort',
#   'pack',
#   'make',
#   'order',
#   'ready',
#   'transport'],
#  ['entire',
#   'team',
#   'wish',
#   'agriculture',
#   'want',
#   'flower',
#   'vegetable',
#   'join',
#   'team'],
#  ['super',
#   'beautiful',
#   'company',
#   'want',
#   'sign',
#   'passing_superver',
#   'dicembre',
#   'want',
#   'sce',
#   'come',
#   'open',
#   'day',
#   'january',
#   'specially',
#   'line',
#   'manager',
#   'function',
#   'register',
#   'directly',
#   'morning',
#   'session',
#   'afternoon',
#   'session',
#   'learn',
#   'know',
#   'pass',
#   'salt',
#   'pour',
#   'receive',
#   'peral',
#   'invitation',
#   'register',
#   'recruitment'],
#  ['forward',
#   'tonic',
#   'november',
#   'lip',
#   'grnhouse',
#   'new',
#   'zealand',
#   'bulb',
#   'nice',
#   'taste',
#   'come',
#   'julie',
#   'sea',
#   'good',
#   'wkend'],
#  ['passing_superver',
#   'settembre',
#   'curious',
#   'beautiful',
#   'company',
#   'carr',
#   'opportunity',
#   'hiss',
#   'visit',
#   'bowl',
#   'company',
#   'day',
#   'happy',
#   'show',
#   'fantastic',
#   'organization',
#   'dog',
#   'allow'],
#  ['drove_dress',
#   'middenmr',
#   'costo',
#   'mlle',
#   'middenmr',
#   'land_settentrionale',
#   'naevi_pass',
#   'race',
#   'man',
#   'construction',
#   'grnhouse',
#   'accommodation',
#   'commute',
#   'provide',
#   'company',
#   'contact',
#   'myaltro',
#   'provide',
#   'information',
#   'phone',
#   'number',
#   'mail_address',
#   'mark',
#   'grting'],
#  ['tonic',
#   'giugno',
#   'ore',
#   'come',
#   'red',
#   'sea',
#   'trigger',
#   'driver',
#   'want',
#   'strengthen',
#   'team',
#   'eg',
#   'sch',
#   'leader',
#   'share',
#   'appreciate'],
#  ['gourmet',
#   'angio',
#   'ore',
#   'come',
#   'summer',
#   'period',
#   'pack',
#   'available',
#   'stts',
#   'year',
#   'holiday',
#   'yet',
#   'already',
#   'finish',
#   'exam',
#   'may',
#   'place',
#   'dity',
#   'contact',
#   'detail',
#   'pp',
#   'contact',
#   'soon',
#   'pible'],
#  ['currently',
#   'conduct',
#   'many',
#   'recruitment',
#   'project',
#   'offer',
#   'deposit',
#   'production',
#   'logistic',
#   'enginre',
#   'administration',
#   'well',
#   'check',
#   'offer',
#   'webster',
#   'inter',
#   'end'],
#  ['company',
#   'produce',
#   'discs',
#   'profile',
#   'gypsy',
#   'wooden',
#   'measure',
#   'glue',
#   'factory',
#   'use',
#   'ship',
#   'navy',
#   'inland',
#   'navigable',
#   'luxury',
#   'gastro',
#   'length',
#   'peter',
#   'company',
#   'currently',
#   'employ',
#   'people',
#   'ability',
#   'team',
#   'important',
#   'currently',
#   'forklift',
#   'operator',
#   'operate',
#   'trolley',
#   'also',
#   'perform',
#   'together',
#   'team',
#   'customer',
#   'people',
#   'want',
#   'eager',
#   'teach',
#   'new',
#   'thing',
#   'inter',
#   'end',
#   'el'],
#  ['administrative',
#   'client',
#   'administration',
#   'office',
#   'typically',
#   'administrative',
#   'function',
#   'registration',
#   'hours',
#   'invoice',
#   'contact',
#   'telephone',
#   'pass',
#   'particle',
#   'altro',
#   'insurance',
#   'new',
#   'people',
#   'loudly',
#   'rate',
#   'discuss',
#   'dndent',
#   'expece',
#   'requirement',
#   'expece',
#   'similar_position',
#   'overview',
#   'knowledge',
#   'dutch',
#   'language',
#   'accommodation',
#   'transport',
#   'good',
#   'knowledge',
#   'expel',
#   'education',
#   'minimum',
#   'average',
#   'inter',
#   'function',
#   'end'],
#  ['specialist',
#   'human',
#   'administration',
#   'kilburn',
#   'e',
#   'datum',
#   'stand',
#   'patrol',
#   'system',
#   'customer',
#   'order',
#   'conduct',
#   'employ',
#   'documentation',
#   'relate',
#   'employment',
#   'relationship',
#   'employment',
#   'form',
#   'service',
#   'polish',
#   'employ',
#   'factory',
#   'starting_date',
#   'remuneration',
#   'dnde',
#   'expece',
#   'customer',
#   'contract',
#   'trial',
#   'period',
#   'requirement',
#   'indndence',
#   'good',
#   'organization',
#   'expece',
#   'similar_position',
#   'welcome',
#   'knowledge',
#   'pernel',
#   'service',
#   'good',
#   'knowledge',
#   'expel',
#   'minimum',
#   'education',
#   'average',
#   'knowledge',
#   'dutch',
#   'language',
#   'minimum',
#   'level',
#   'inter',
#   'function',
#   'end'],
#  ['immediately',
#   'offer',
#   'collect',
#   'sort',
#   'grnhouse',
#   'longer_period',
#   'time',
#   'workplace',
#   'mere',
#   'requirement',
#   'motivation',
#   'willing',
#   'start',
#   'immediately',
#   'offer',
#   'retro',
#   'legal',
#   'trust',
#   'prove',
#   'employer',
#   'stake',
#   'loudly',
#   'guarantd',
#   'complaint',
#   'dutch',
#   'labor',
#   'ride',
#   'legal',
#   'employment',
#   'social',
#   'benefit',
#   'drainage',
#   'pion',
#   'contribution',
#   'detailed',
#   'presentation',
#   'employment',
#   'condition',
#   'transport',
#   'wkly_payment',
#   'employ',
#   'account',
#   'inter',
#   'ask',
#   'send',
#   'polish',
#   'english'],
#  ['offer',
#   'dutch',
#   'grnhouse',
#   'deal',
#   'grow',
#   'pepper',
#   'employ',
#   'task',
#   'primarily',
#   'belong',
#   'plant',
#   'plant',
#   'remove',
#   'impairment',
#   'requs',
#   'minimum',
#   'basicjaltro',
#   'knowledge',
#   'nez',
#   'english',
#   'willing',
#   'additional_advantage',
#   'driving_lice',
#   'offer',
#   'earning',
#   'tailor',
#   'expectation',
#   'cao',
#   'people',
#   'year',
#   'low',
#   'rate',
#   'accommodation',
#   'ewaype',
#   'low',
#   'dutch',
#   'statement',
#   'holiday',
#   'allowance',
#   'addition',
#   'regular',
#   'hour',
#   'transport',
#   'organization',
#   'accommodation',
#   'coordual',
#   'cheap',
#   'address',
#   'info'],
#  ['client',
#   'motivate',
#   'employ',
#   'hear',
#   'pepper',
#   'requirement',
#   'residence',
#   'communicative',
#   'knowledge',
#   'english',
#   'dutch',
#   'driving_lice',
#   'welcome',
#   'transport',
#   'inter',
#   'per',
#   'send',
#   'mail_address'],
#  ['offer',
#   'start',
#   'day',
#   'silk',
#   'factory',
#   'require',
#   'driving_lice',
#   'english',
#   'communicative',
#   'physical',
#   'force',
#   'carpet',
#   'factory',
#   'require',
#   'driving_lice',
#   'english',
#   'communicative',
#   'physical_strength',
#   'grnhouse',
#   'pepper',
#   'expece',
#   'edge',
#   'shoot',
#   'break',
#   'supper',
#   'seat',
#   'plant',
#   'expece',
#   'knife',
#   'poultry',
#   'lifetime',
#   'chick'],
#  ['current',
#   'offer',
#   'production',
#   'knife',
#   'poultry',
#   'lifetime',
#   'production',
#   'production',
#   'carpet',
#   'agriculture',
#   'invasion',
#   'defe',
#   'overview'],
#  ['current',
#   'offer',
#   'say',
#   'belgium',
#   'important',
#   'annual',
#   'expece',
#   'profession',
#   'forklift',
#   'operator',
#   'pission',
#   'bf',
#   'butcher',
#   'expece',
#   'carpet',
#   'factory',
#   'driving_lice',
#   'language',
#   'physical_strength',
#   'production',
#   'driving_lice',
#   'language',
#   'physical_strength',
#   'invasion',
#   'requirement'],
#  ['harden',
#   'grnhouse',
#   'grnhouse',
#   'crop',
#   'collect',
#   'fruit',
#   'plant',
#   'care',
#   'cleaning',
#   'sorting',
#   'plant',
#   'date',
#   'start',
#   'organize',
#   'wk',
#   'content',
#   'mail',
#   'give',
#   'day',
#   'ready',
#   'go',
#   'abroad',
#   'number',
#   'vacancy',
#   'austro',
#   'apply',
#   'offer',
#   'send',
#   'title',
#   'message',
#   'message',
#   'give',
#   'start',
#   'phone',
#   'number',
#   'send',
#   'check',
#   'datum',
#   'correct',
#   'name',
#   'surname',
#   'date',
#   'birth',
#   'address',
#   'contact',
#   'detail',
#   'absence',
#   'datum',
#   'may',
#   'consider',
#   'day',
#   'bound',
#   'company',
#   'inform',
#   'status',
#   'application'],
#  ['temporary',
#   'employ',
#   'offer',
#   'receive',
#   'contract',
#   'employment',
#   'foreign',
#   'employer',
#   'contract',
#   'citiz',
#   'tax',
#   'insurance',
#   'contribution',
#   'pay',
#   'due',
#   'tax',
#   'refund',
#   'certain',
#   'accordance',
#   'labor',
#   'ride',
#   'accommodation',
#   'accommodation',
#   'space',
#   'accommodation',
#   'ualtro',
#   'terrify',
#   'employer',
#   'regeneration',
#   'accordance',
#   'rate',
#   'applicable',
#   'requirement',
#   'ability',
#   'availability',
#   'immediately',
#   'motivation',
#   'driving_lice',
#   'optional',
#   'sob',
#   'fromremove',
#   'harve',
#   'bytime',
#   'start',
#   'organize',
#   'wk',
#   'content',
#   'mail',
#   'give',
#   'day',
#   'ready',
#   'go',
#   'abroad',
#   'number',
#   'vacancy',
#   'stand',
#   'apply',
#   'offer',
#   'send',
#   'ab',
#   'title',
#   'message',
#   'message',
#   'give',
#   'start',
#   'phone',
#   'number',
#   'send',
#   'check',
#   'datum',
#   'correct'],
#  ['check',
#   'offer',
#   'apply',
#   'today',
#   'assistant',
#   'team_leader',
#   'rise',
#   'logistic',
#   'worker',
#   'warehouse',
#   'furniture',
#   'vessel',
#   'process',
#   'operator',
#   'galwanizer',
#   'kilburn',
#   'http',
#   'eld',
#   'tig',
#   'hooger',
#   'guarant',
#   'transport',
#   'check',
#   'offer',
#   'webster',
#   'contact',
#   'also',
#   'send',
#   'order',
#   'recruitment',
#   'department'],
#  ['check',
#   'offer',
#   'apply',
#   'today',
#   'logistic',
#   'worker',
#   'luxury',
#   'warehouse',
#   'furniture',
#   'ethel',
#   'operator',
#   'forklift',
#   'reruck',
#   'warehouse',
#   'latro',
#   'worker',
#   'production',
#   'cartridge',
#   'flower',
#   'pot',
#   'bread',
#   'operator',
#   'cnc',
#   'edge',
#   'press',
#   'hooger',
#   'driver',
#   'hook',
#   'guarant',
#   'transport',
#   'check',
#   'offer',
#   'site',
#   'contact',
#   'also',
#   'unload',
#   'order',
#   'recruitment',
#   'department',
#   'http'],
#  ['search',
#   'driver',
#   'driving_lice',
#   'drive',
#   'car',
#   'offer',
#   'position',
#   'category',
#   'driver',
#   'compact',
#   'ready',
#   'full',
#   'commitment',
#   'company',
#   'spch',
#   'maybe',
#   'wait',
#   'end',
#   'application',
#   'contact',
#   'phone',
#   'order',
#   'order',
#   'recruitment',
#   'department'],
#  ['inter',
#   'supplement',
#   'would',
#   'know',
#   'whole',
#   'process',
#   'create',
#   'whole',
#   'shipping',
#   'process',
#   'familiarize',
#   'offer',
#   'webster',
#   'bring',
#   'close',
#   'gastro',
#   'desire',
#   'carr',
#   'everything',
#   'detail',
#   'offer',
#   'offer',
#   'find',
#   'webster',
#   'end',
#   'application',
#   'contact',
#   'phone',
#   'order',
#   'order',
#   'recruitment',
#   'department'],
#  ['want',
#   'immediately',
#   'village',
#   'kilburn',
#   'production',
#   'wooden',
#   'roof',
#   'element',
#   'people',
#   'expece',
#   'also',
#   'people',
#   'gastro',
#   'account',
#   'offer',
#   'always',
#   'transport',
#   'pnt',
#   'long_period',
#   'time',
#   'development',
#   'opportunity',
#   'company',
#   'offer',
#   'detail',
#   'find',
#   'check',
#   'offer',
#   'webster',
#   'contact',
#   'also',
#   'unload',
#   'order',
#   'recruitment',
#   'department',
#   'http'],
#  ['kilburn',
#   'surrounding',
#   'check',
#   'offer',
#   'production',
#   'worker',
#   'fix',
#   'color',
#   'color',
#   'kilburn',
#   'logistic',
#   'worker',
#   'elektronika',
#   'wijk',
#   'kilburn',
#   'altrohttps',
#   'collection',
#   'order',
#   'art',
#   'good',
#   'kilburn',
#   'kilburn',
#   'production',
#   'soda',
#   'soda_stream',
#   'give',
#   'always',
#   'offer',
#   'transport',
#   'check',
#   'offer',
#   'webster',
#   'contact',
#   'also',
#   'unload',
#   'order',
#   'recruitment',
#   'department'],
#  ['guarantd',
#   'transport',
#   'busis',
#   'car',
#   'organize',
#   'transport',
#   'information',
#   'recruit',
#   'recruitment',
#   'department',
#   'order',
#   'also',
#   'send',
#   'contact'],
#  ['accommodation',
#   'guarantd',
#   'transport',
#   'report',
#   'logistic',
#   'worker',
#   'elektronika',
#   'wijk',
#   'kilburn',
#   'collection',
#   'order',
#   'good',
#   'retro',
#   'kilburn',
#   'production',
#   'cartridge',
#   'flower',
#   'pot',
#   'red',
#   'support',
#   'operator',
#   'production',
#   'pharmaceutical',
#   'kilburn',
#   'production',
#   'soda',
#   'soda_stream',
#   'give',
#   'http_bit',
#   'always',
#   'offer',
#   'transport',
#   'check',
#   'offer',
#   'webster',
#   'contact',
#   'also',
#   'unload',
#   'order',
#   'recruitment',
#   'department'],
#  ['logistic',
#   'deal',
#   'warehouse',
# ...
#  ['grn',
#   'finger',
#   'vegetable',
#   'holiday',
#   'force',
#   'also',
#   'welcome',
#   'available',
#   'longer_period',
#   'time',
#   'contact'],
#  ['logistic',
#   'wrecker',
#   'attention',
#   'electronic',
#   'up',
#   'moduslink',
#   'immediately',
#   'lift',
#   'reach_truck',
#   'driver',
#   'minimum',
#   'month',
#   'expece',
#   'full',
#   'time',
#   'available',
#   'check',
#   'profile',
#   'apply'],
#  ['pay',
#   'vacation',
#   'wkend',
#   'various',
#   'lumbo',
#   'holiday',
#   'wkend',
#   'force',
#   'order_picker',
#   'lumbo',
#   'make',
#   'order',
#   'ready',
#   'handaltrole',
#   'list',
#   'shop',
#   'large',
#   'suparket',
#   'check',
#   'profile',
#   'new',
#   'vacation'],
#  ['distribution',
#   'know',
#   'suparket',
#   'chain',
#   'still',
#   'holiday',
#   'wkend',
#   'force',
#   'available',
#   'summer',
#   'wk',
#   'pay',
#   'process',
#   'use',
#   'aid',
#   'dealtro',
#   'vacation',
#   'basis',
#   'list',
#   'set',
#   'order',
#   'order',
#   'customer',
#   'shop',
#   'large',
#   'suparket',
#   'come',
#   'strengthen',
#   'master',
#   'team',
#   'apply'],
#  ['think',
#   'summer',
#   'summer',
#   'plan',
#   'come',
#   'true',
#   'go',
#   'packer',
#   'choose',
#   'flexible',
#   'detine',
#   'day',
#   'clean',
#   'environment',
#   'pleasant',
#   'team',
#   'ready',
#   'summer',
#   'apply'],
#  ['want',
#   'tommy',
#   'hilfger',
#   'chance',
#   'distribution',
#   'tommy_hilfiger',
#   'warehouse',
#   'worker',
#   'available',
#   'know',
#   'english',
#   'dutch',
#   'inter',
#   'apply',
#   'man',
#   'woman',
#   'tommy_hilfiger'],
#  ['apply',
#   'quickly',
#   'start',
#   'immediately',
#   'read',
#   'continue',
#   'soon',
#   'apply',
#   'site',
#   'call',
#   'colleague',
#   'vacancy',
#   'almond',
#   'telephone',
#   'numbercover',
#   'world',
#   'employ',
#   'create',
#   'stl',
#   'book',
#   'decoration'],
#  ['new',
#   'colleague',
#   'nice',
#   'salary',
#   'get',
#   'happy',
#   'full',
#   'time',
#   'part',
#   'time',
#   'friday',
#   'saturday',
#   'available',
#   'lumbo',
#   'alro',
#   'place',
#   'new',
#   'employ',
#   'start',
#   'immediately',
#   'wait',
#   'longer',
#   'apply',
#   'order_picker',
#   'lumbo',
#   'red'],
#  ['top',
#   'full',
#   'time',
#   'part',
#   'time',
#   'friday',
#   'saturday',
#   'available',
#   'new',
#   'employ',
#   'distribution',
#   'larg',
#   'suparket',
#   'start',
#   'immediately',
#   'wait',
#   'longer',
#   'apply',
#   'implicate',
#   'otto',
#   'force'],
#  ['know',
#   'tackle',
#   'live',
#   'neighborhood',
#   'red',
#   'least',
#   'saturday',
#   'pibly',
#   'day',
#   'also',
#   'respond',
#   'leave',
#   'datum',
#   'contact',
#   'meet',
#   'start',
#   'quickly',
#   'respond',
#   'saturday',
#   'area',
#   'good',
#   'food',
#   'start',
#   'quickly'],
#  ['specialist',
#   'responsible',
#   'daily',
#   'course',
#   'affair',
#   'location',
#   'recruitment',
#   'election',
#   'pernel',
#   'planning',
#   'administration',
#   'commercial',
#   'customer_tormented',
#   'attitude',
#   'speak',
#   'polish',
#   'dutch',
#   'language',
#   'view',
#   'vacancy',
#   'respond',
#   'directly',
#   'online'],
#  ['january',
#   'isu',
#   'round',
#   'championship',
#   'take',
#   'place',
#   'warsaw',
#   'hereby',
#   'promotion',
#   'film',
#   'star',
#   'state',
#   'sponsor',
#   'otto',
#   'force',
#   'dni',
#   'cargo',
#   'promo',
#   'european',
#   'championship',
#   'spdskate',
#   'warsaw'],
#  ['polish',
#   'man',
#   'chase',
#   'team',
#   'state',
#   'today',
#   'bronze',
#   'medal',
#   'final',
#   'world',
#   'hrenvn',
#   'polish',
#   'team',
#   'also',
#   'become',
#   'third',
#   'general',
#   'classification',
#   'thesea',
#   'ottoworkforce',
#   'novel',
#   'jerk',
#   'cargo',
#   'hrenvn',
#   'naevi_pass',
#   'iii',
#   'miejsce',
#   'drużyny',
#   'męskiej',
#   'całej',
#   'edycji',
#   'pucharu',
#   'świata'],
#  ['specially',
#   'occasion',
#   'woman',
#   'may',
#   'present',
#   'offer',
#   'beautiful',
#   'sex',
#   'want',
#   'modern',
#   'factory',
#   'machi',
#   'responsible',
#   'entire',
#   'production',
#   'process',
#   'waveform',
#   'production',
#   'product',
#   'larg',
#   'advantage',
#   'high',
#   'rate',
#   'ruling',
#   'pay',
#   'wkly',
#   'employ_receive',
#   'pack',
#   'meat',
#   'additional',
#   'surcharist',
#   'apply',
#   'today',
#   'watch',
#   'movie',
#   'get',
#   'inspire',
#   'otto',
#   'force'],
#  ['specially',
#   'occasion',
#   'international',
#   'woman',
#   'day',
#   'present',
#   'attractive',
#   'woman',
#   'want',
#   'modern',
#   'factory',
#   'machi',
#   'packet',
#   'hisaltro',
#   'hand',
#   'pay',
#   'attention',
#   'quality',
#   'important',
#   'benefit',
#   'great',
#   'salary',
#   'pay',
#   'package',
#   'fresh',
#   'meat',
#   'lunch',
#   'afternoon',
#   'service',
#   'apply',
#   'watch',
#   'video',
#   'convinced',
#   'otto',
#   'force'],
#  ['saturday',
#   'day',
#   'busis',
#   'woman',
#   'congress',
#   'platino',
#   'sponsor',
#   'busis',
#   'woman',
#   'event',
#   'busis',
#   'woman',
#   'congress',
#   'cargo',
#   'day',
#   'leave',
#   'saturday'],
#  ['kind',
#   'convincing',
#   'phone',
#   'speak',
#   'polish',
#   'english',
#   'gan',
#   'switch',
#   'betwn',
#   'thr',
#   'language',
#   'quickly',
#   'function',
#   'call',
#   'employ',
#   'certainly',
#   'something',
#   'know',
#   'quickly'],
#  ['specialist',
#   'make',
#   'difference',
#   'nice',
#   'strengthen',
#   'operation',
#   'team',
#   'specialist',
#   'region',
#   'expece',
#   'inaltro',
#   'similar',
#   'function',
#   'communicative',
#   'strong',
#   'customer_tormented',
#   'view',
#   'profile',
#   'apply',
#   'directly',
#   'online'],
#  ['electronic',
#   'henry',
#   'yard',
#   'employ',
#   'position',
#   'responsible',
#   'guide',
#   'instruct',
#   'driver',
#   'parking',
#   'loading',
#   'unloading',
#   'inter',
#   'apply',
#   'vacancy',
#   'yard',
#   'employ',
#   'administrative',
#   'employ',
#   'distribution'],
#  ['want',
#   'producer',
#   'car',
#   'part',
#   'precede',
#   'agar',
#   'mania',
#   'volkswagen',
#   'among_other',
#   'line',
#   'production',
#   'staff',
#   'inter',
#   'view',
#   'full',
#   'vacancy',
#   'apply',
#   'vacancy',
#   'production',
#   'staff',
#   'automotive'],
#  ['brezan',
#   'car',
#   'material',
#   'new',
#   'colleague',
#   'order_picker',
#   'collect_order',
#   'make',
#   'ready',
#   'dispatch',
#   'happ',
#   'voice',
#   'stick',
#   'system',
#   'takes_place',
#   'tear',
#   'something',
#   'apply',
#   'vacancy',
#   'ordicker',
#   'brezan',
#   'automaterialen'],
#  ['vacancy',
#   'officer',
#   'distribution',
#   'position',
#   'play',
#   'important',
#   'role',
#   'physical',
#   'distribution',
#   'relate',
#   'activity',
#   'find',
#   'wkend',
#   'day',
#   'day',
#   'night',
#   'problem',
#   'view',
#   'vacancy',
#   'apply'],
#  ['maintenance',
#   'enginr',
#   'renowned',
#   'european',
#   'distribution',
#   'aromatic',
#   'candle',
#   'indndently',
#   'also',
#   'ures',
#   'development',
#   'new',
#   'colleague',
#   'goedaltro',
#   'view',
#   'contract',
#   'partylite',
#   'head',
#   'complete',
#   'profile',
#   'apply',
#   'directly',
#   'online'],
#  ['earn',
#   'beautiful',
#   'expece',
#   'otto',
#   'force',
#   'extive',
#   'range',
#   'full',
#   'time',
#   'part',
#   'time',
#   'ultimately',
#   'give',
#   'frdom',
#   'want',
#   'live',
#   'right',
#   'check',
#   'overview',
#   'apply',
#   'online'],
#  ['beautiful',
#   'expece',
#   'otto',
#   'force',
#   'wide',
#   'range',
#   'full',
#   'part',
#   'time',
#   'finally',
#   'able',
#   'want',
#   'live',
#   'check',
#   'offer',
#   'immediately',
#   'apply',
#   'line'],
#  ['gipman',
#   'inpacker',
#   'pack',
#   'garden',
#   'expece',
#   'production',
#   'grnhouse',
#   'apply',
#   'vacancy'],
#  ['want',
#   'manager',
#   'planning',
#   'expece',
#   'planner',
#   'logistic',
#   'industry',
#   'manage',
#   'dutch',
#   'english',
#   'polish',
#   'language',
#   'word',
#   'writing',
#   'offer',
#   'cenge',
#   'responsible',
#   'function',
#   'competitive',
#   'salary',
#   'excent',
#   'secondary',
#   'employment',
#   'condition',
#   'apply',
#   'online',
#   'right_away'],
#  ['want',
#   'recruitment',
#   'train',
#   'want',
#   'internship',
#   'larg',
#   'international',
#   'employment',
#   'broker',
#   'europe',
#   'want',
#   'get',
#   'know',
#   'commercial',
#   'side',
#   'employment',
#   'mediation',
#   'well',
#   'chance',
#   'train',
#   'recruitment',
#   'department',
#   'apply',
#   'directly',
#   'online'],
#  ['great',
#   'place',
#   'company',
#   'autojobile_industry',
#   'good',
#   'salary',
#   'directly',
#   'border',
#   'henry',
#   'production',
#   'staff',
#   'want',
#   'make',
#   'assembly',
#   'analtro',
#   'task',
#   'long',
#   'time',
#   'expece',
#   'production',
#   'craftsmanship',
#   'good',
#   'gan',
#   'language',
#   'skill',
#   'ready',
#   'layer',
#   'head',
#   'complete',
#   'profile',
#   'apply',
#   'directly',
#   'online'],
#  ['vice',
#   'vacancy',
#   'autojobile',
#   'good',
#   'merit',
#   'production',
#   'force',
#   'want',
#   'assembly',
#   'employ',
#   'longer_period',
#   'time',
#   'precise',
#   'expece',
#   'productionaltro',
#   'use',
#   'flexibly',
#   'early',
#   'full',
#   'profile',
#   'check',
#   'apply',
#   'directly',
#   'online'],
#  ['full',
#   'time',
#   'ordicker',
#   'problem',
#   'shift',
#   'vice',
#   'chance',
#   'order_picket',
#   'brezan',
#   'car',
#   'material',
#   'ordicker',
#   'automaterialen',
#   'otto',
#   'force'],
#  ['place',
#   'busy',
#   'agenda',
#   'want',
#   'make',
#   'money',
#   'addition',
#   'study',
#   'fun',
#   'assistance',
#   'attractive',
#   'salary',
#   'lumbo',
#   'distribution',
#   'men_porch',
#   'belangro',
#   'respond',
#   'message',
#   'send',
#   'facebook',
#   'contact',
#   'immediately',
#   'full',
#   'time',
#   'available',
#   'top',
#   'also',
#   'full',
#   'time',
#   'check',
#   'profile'],
#  ['speak',
#   'bluntly',
#   'gan',
#   'want',
#   'get',
#   'start',
#   'international',
#   'company',
#   'apply',
#   'production',
#   'employ',
#   'international',
#   'vnendaal',
#   'otto',
#   'force'],
#  ['line',
#   'manager',
#   'banking',
#   'mushroom',
#   'kitchen',
#   'accurate',
#   'quality',
#   'guard',
#   'managerial',
#   'expece',
#   'check',
#   'full',
#   'profile',
#   'apply',
#   'vacancy',
#   'line',
#   'manager',
#   'take',
#   'champignon',
#   'kitchen'],
#  ['offer',
#   'order_picker',
#   'lumbo',
#   'get',
#   'start',
#   'department',
#   'suit',
#   'collect_order',
#   'delete',
#   'care',
#   'enthusiastic',
#   'team',
#   'neat',
#   'environment',
#   'inter',
#   'check',
#   'profile',
#   'apply',
#   'online',
#   'vacancy',
#   'ordicker',
#   'lumbo',
#   'red'],
#  ['order_picker',
#   'want',
#   'would',
#   'like',
#   'gain',
#   'expece',
#   'large',
#   'logistic',
#   'player',
#   'informal',
#   'environment',
#   'pleasant',
#   'colleague',
#   'apply',
#   'quickly',
#   'vacancy',
#   'order_picked',
#   'vacancy',
#   'ordicker'],
#  ['hard',
#   'worker',
#   'motivate',
#   'drive',
#   'hand',
#   'mentality',
#   'available',
#   'immediately',
#   'staff',
#   'wholesale',
#   'clothing',
#   'inter',
#   'view',
#   'vacancy',
#   'apply',
#   'note',
#   'heavy',
#   'many',
#   'lifting',
#   'walk',
#   'vacancy',
#   'warehouse',
#   'staff',
#   'wholesale',
#   'clothing'],
#  ['employ',
#   'operation',
#   'customer',
#   'food',
#   'fresh',
#   'industry',
#   'quality',
#   'innovation',
#   'service',
#   'paramount',
#   'importance',
#   'knowledge',
#   'dutch',
#   'english',
#   'polish',
#   'language',
#   'view',
#   'vacancy',
#   'apply',
#   'vacancy',
#   'employ',
#   'operation'],
#  ['year',
#   'otto',
#   'foundation',
#   'support',
#   'homeless',
#   'dinner',
#   'pole',
#   'city',
#   'otto',
#   'start',
#   'poland',
#   'leadership',
#   'operational',
#   'director',
#   'carolina',
#   'sloboda',
#   'otto',
#   'foundation',
#   'today',
#   'give',
#   'less',
#   'unate',
#   'special',
#   'christmas',
#   'dinner',
#   'head',
#   'heart',
#   'e',
#   'initiative',
#   'alone',
#   'christmas',
#   'otto',
#   'foundation',
#   'support',
#   'homeless',
#   'dinner',
#   'pole',
#   'city',
#   'otto',
#   'start',
#   'poland',
#   'otto',
#   'force'],
#  ['full',
#   'time',
#   'part',
#   'time',
#   'friday',
#   'saturday',
#   'available',
#   'warehouse',
#   'staff',
#   'distribution',
#   'larg',
#   'suparket_chain',
#   'apply',
#   'vacancy',
#   'warehouse',
#   'employ'],
#  ['seek',
#   'warehouse',
#   'staff',
#   'indndently',
#   'good',
#   'focus',
#   'part',
#   'fun',
#   'close',
#   'team',
#   'check',
#   'vacancy',
#   'apply',
#   'warehouse',
#   'employ',
#   'wholesale',
#   'clothing'],
#  ['want',
#   'pay',
#   'train',
#   'machine_operator',
#   'hilton',
#   'seat',
#   'read',
#   'quickly',
#   'serious',
#   'candidate',
#   'start',
#   'production',
#   'strength',
#   'want',
#   'follow',
#   'learn',
#   'trajectory',
#   'begin',
#   'able',
#   'completely',
#   'indndently',
#   'machine_operator',
#   'year',
#   'want',
#   'inv',
#   'future',
#   'check',
#   'full',
#   'immediately',
#   'apply',
#   'online'],
#  ['expece',
#   'fig',
#   'bag',
#   'speak',
#   'english',
#   'want',
#   'belgium',
#   'benefit',
#   'accommodation',
#   'health_insurance',
#   'transportalro',
#   'back',
#   'holiday_money',
#   'apply',
#   'online',
#   'send',
#   'resume',
#   'mail',
#   'emigre',
#   'contact',
#   'next',
#   'busis',
#   'day',
#   'information',
#   'contact',
#   'phone',
#   'atlanta',
#   'super',
#   'eld',
#   'belgium'],
#  ['jobulzile',
#   'expece',
#   'burgher',
#   'drive',
#   'driving_lice',
#   'know',
#   'english',
#   'want',
#   'stability',
#   'long',
#   'project',
#   'apply',
#   'dealtro',
#   'end',
#   'resume',
#   'mail',
#   'contact'],
#  ['want',
#   'current',
#   'bring',
#   'satisfaction',
#   'appreciate',
#   'true',
#   'value',
#   'think',
#   'anything',
#   'else',
#   'better',
#   'pay',
#   'analtro',
#   'answer',
#   'quion',
#   'case',
#   'get',
#   'know',
#   'well',
#   'emigre_sobs',
#   'number',
#   'mania',
#   'come',
#   'peral',
#   'recruitment',
#   'technical',
#   'construction',
#   'expece',
#   'project',
#   'take',
#   'place',
#   'belgium',
#   'people',
#   'valuable',
#   'ambitious',
#   'taed',
#   'motivate',
#   'contact',
#   'mail',
#   'phone',
#   'stand',
#   'find',
#   'motivate',
#   'cariera',
#   'ovigrejobs',
#   'opptunity',
#   'emigre_sobs'],
#  ['jobulzile',
#   'expece',
#   'burgher',
#   'drive',
#   'driving_lice',
#   'know',
#   'english',
#   'want',
#   'stability',
#   'long',
#   'project',
#   'apply',
#   'apply',
#   'online',
#   'contact',
#   'apply'],
#  ['nowhire',
#   'belgium',
#   'open',
#   'position',
#   'emigre',
#   'carp',
#   'join',
#   'concrete_carp',
#   'prefer',
#   'carp',
#   'timber',
#   'frame',
#   'builder',
#   'factory',
#   'carp',
#   'bricklayeraltro',
#   'roof',
#   'painter',
#   'decoration',
#   'plasterer',
#   'tile',
#   'setter',
#   'concrete',
#   'finish',
#   'domic_plumber',
#   'pipe',
#   'bitter',
#   'large',
#   'mechanic',
#   'fig_may',
#   'eld',
#   'fig',
#   'elder',
#   'bend',
#   'machine_operator',
#   'turner',
#   'fancy',
#   'heavy',
#   'equipment',
#   'mechanic',
#   'agricultural',
#   'mechanic',
#   'truck',
#   'mechanic',
#   'find',
#   'good',
#   'ure',
#   'nice',
#   'stay',
#   'belgium',
#   'count',
#   'peral',
#   'coordinator',
#   'coach',
#   'inform',
#   'everything',
#   'nd',
#   'know',
#   'cooperation',
#   'always',
#   'reliable',
#   'energetic',
#   'people',
#   'join',
#   'team',
#   'sound',
#   'mail',
#   'emigre'],
#  ['jobofthewk',
#   'applynow',
#   'emigre',
#   'maggie',
#   'ore',
#   'facebook',
#   'andro',
#   'large',
#   'project',
#   'zip',
#   'bricklayer',
#   'already',
#   'familiar',
#   'dutch',
#   'method',
#   'quality',
#   'standard',
#   'start',
#   'right_away',
#   'project',
#   'locate',
#   'andaltro',
#   'consist',
#   'new',
#   'construction',
#   'apartment',
#   'building',
#   'client',
#   'constant',
#   'year',
#   'inter',
#   'respond_quickly',
#   'send',
#   'mail_address',
#   'contract',
#   'recruit',
#   'day',
#   'quion',
#   'get',
#   'touch',
#   'office',
#   'follow',
#   'number'],
#  ['belgian',
#   'customer',
#   'currently_recruite',
#   'number',
#   'factory',
#   'carp',
#   'like',
#   'cut',
#   'abdicate',
#   'wooden',
#   'structure',
#   'accord',
#   'specification',
#   'passionate',
#   'carp',
#   'thinkingaltro',
#   'change',
#   'day',
#   'may',
#   'something',
#   'inter',
#   'start',
#   'right_away',
#   'benefits_excent',
#   'condition',
#   'good',
#   'start',
#   'salary',
#   'good',
#   'accommodation',
#   'provide',
#   'single_room',
#   'child',
#   'benefit',
#   'child',
#   'holiday',
#   'end',
#   'year',
#   'bonus',
#   'inter',
#   'apply',
#   'send',
#   'mail_address',
#   'review',
#   'profile',
#   'check',
#   'pibilitie',
#   'match',
#   'contact',
#   'discuss',
#   'set',
#   'interview',
#   'quion',
#   'want',
#   'know',
#   'get',
#   'touch',
#   'office',
#   'follow',
#   'number'],
#  ['willing',
#   'consider',
#   'pibility',
#   'become',
#   'zip_er',
#   'know',
#   'start',
#   'great',
#   'news',
#   'right',
#   'place',
#   'may',
#   'also',
#   'afraid',
#   'ofaltro',
#   'everything',
#   'frlance',
#   'busis',
#   'would',
#   'involve',
#   'cost',
#   'taxis',
#   'administration',
#   'let',
#   'first',
#   'go',
#   'frlance',
#   'probably',
#   'much',
#   'easy',
#   'think',
#   'emigre',
#   'guide',
#   'become',
#   'official',
#   'frlancer',
#   'find',
#   'first',
#   'client',
#   'time',
#   'money',
#   'get',
#   'touch',
#   'today'],
#  ...]

# %%
# Join the different processed texts together.
long_string = ','.join([','.join(text) for text in data_lemmatized])

wordcloud = WordCloud(background_color="white", contour_width=3,colormap='binary',width=800, height=400)

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x139D2C8FC18>

# %%
from collections import Counter
wordcount = Counter(long_string.split(','))
sorted_wordcount = sorted(list(wordcount.items()), key=lambda x: x[1],reverse=True)
sorted_wordcount[:10]
# Out:
# [('offer', 1364),
#  ('english', 1014),
#  ('accommodation', 936),
#  ('production', 877),
#  ('transport', 877),
#  ('expece', 861),
#  ('dutch', 667),
#  ('contact', 646),
#  ('hour', 585),
#  ('apply', 578)]

# %%
sns.set_style('whitegrid')

# %matplotlib inline
# Helper function
def plot_10_most_common_words(data):
    import matplotlib.pyplot as plt
    words = [w[0] for w in data[0:10]]
    counts = [w[1] for w in data[0:10]]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='binary')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()

# Visualise the 10 most common words
plot_10_most_common_words(sorted_wordcount)
# Out:
# C:\Users\david\anaconda3\envs\thesis\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
